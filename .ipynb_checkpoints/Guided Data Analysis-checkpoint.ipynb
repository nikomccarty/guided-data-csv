# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Loading in a CSV file

# %%
# Store the entire CSV file in a variable called 'df'
df = pd.read_csv('../../database_export.csv')

# %%
# Let's take a look at the database using 'head,' which shows first five rows
# in the database.
df.head()
# Out:
#    Record ID                                              Title  \
# 0      29142  A Human Torque Teno Virus Encodes a MicroRNA T...
# 1      29140  AIB1 Cooperates with ERα to Promote Epithelial...
# 2      29146  DCLK1 promotes epithelial-mesenchymal transiti...
# 3      29141  TDP-43 causes neurotoxicity and cytoskeletal d...
# 4      29105  The Race to Herd Immunity: Results From a Larg...
#
#                                              Subject  \
# 0                 (BLS) Genetics;(BLS) Microbiology;
# 1  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 2  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 3  (BLS) Biochemistry;(BLS) Biology - Cellular;(B...
# 4  (HSC) Medicine - Infectious Disease;(HSC) Publ...
#
#                                          Institution  \
# 0  The University of Texas at Austin, Molecular G...
# 1  School of Life Science and Biotechnology, Dali...
# 2  Tianjin Life Science Research Center and Depar...
# ...

# %%
# We can also gather 'summary information,' such as the data types in the database, by typing .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27078 entries, 0 to 27077
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              27078 non-null  int64
#  1   Title                  27078 non-null  object
#  2   Subject                27078 non-null  object
#  3   Institution            27068 non-null  object
#  4   Journal                27077 non-null  object
#  5   Publisher              27077 non-null  object
#  6   Country                27068 non-null  object
#  7   Author                 27065 non-null  object
#  8   URLS                   14443 non-null  object
#  9   ArticleType            27078 non-null  object
#  10  RetractionDate         27078 non-null  object
#  11  RetractionDOI          26418 non-null  object
#  12  RetractionPubMedID     18603 non-null  float64
#  13  OriginalPaperDate      27078 non-null  object
# ...

# %% [markdown]
# ## Pulling All Entries with a Certain Author

# %%
df_authors = df[df['Author'].str.contains('Baskaran')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5eb1e240500a> in <module>
# ----> 1 df_authors = df[df['Author'].str.contains('Baskaran')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
Affiliations filtering
Pull out all authors, alphabetical
Importing and exporting data
All papers by one author
Course recommendations to Abritis
Isolate for a specific reason, but not that reason, etc.
Plotting basics, numpy, pandas
